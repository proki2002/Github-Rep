# %%
import numpy as np 
from matplotlib import pyplot as plt 
import pandas as pd 
from numpy import nan

# %%
f = pd.read_excel('dane.xlsx')

# %%
p=[]
for i in range(7):
    p.append(i)
    p[i]=f[f.columns[i]].values.tolist()
t=p[-1]
p.remove(t)
k=[[],[],[],[],[],[]]
for j in range(len(p)):
    for item in p[j]:
        if str(item) != 'nan':
            k[j].append(float(str(item)[:-1]))

# %%
p=k
p[1].pop(3)
tytuły=['100,00%','80,00%','61,00%','54,00%','35,00%','22,00%']
plt.figure(figsize=(10,8))
for i in range(len(p)):
    plt.subplot(2,3,i+1)
    plt.scatter(t[0:len(p[i])],p[i],color='k',marker='.')
    plt.plot(t[0:len(p[i])],p[i],color='r')
    plt.style.use('seaborn-whitegrid')
    plt.xlabel("Czas $t$ [min]")
    plt.ylabel("Temperatura $T$ [°C]")
    plt.title(tytuły[i]+' wag. naftalenu')
    plt.tight_layout()
plt.show()
