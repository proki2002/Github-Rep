# %%
import numpy as np 
from matplotlib import pyplot as plt 
import pandas as pd 
from numpy import nan

# %%
f = pd.read_excel('dane.xlsx')
c=f[f.columns[0]].values.tolist()
z=f[f.columns[1]].values.tolist()
z=[x for x in z if str(x)!='nan'] #20 przejść o 1/2 lambda ergo zmiana o 10 lambda
c=[x for x in c if str(x)!='nan']
lc=636
lz=532

# %%
class W:
    def __init__(self,pomiary:list,l:int):
        self.p=np.array(pomiary)
        self.l=l
    def wykres(self):
        self.suma=[np.sum(self.p[:x]) for x in range(len(self.p))]
        self.p=self.p*10**5/self.l
        plt.plot(self.suma,self.p)
        plt.show()

# %%
z=W(z,lz)
z.wykres(), z.p, z.suma
# Out:
# (None,
#  array([22.55639098, 22.55639098, 16.91729323, 13.15789474, 13.15789474]),
#  [0.0, 0.12, 0.24, 0.32999999999999996, 0.39999999999999997])

# %%
c=W(c,lc)
c.wykres(), c.p, c.suma
# Out:
# (None,
#  array([20.44025157, 15.72327044, 15.72327044, 14.1509434 , 14.1509434 ,
#         12.57861635, 12.57861635, 14.1509434 ]),
#  [0.0, 0.13, 0.23, 0.33, 0.42000000000000004, 0.51, 0.59, 0.6699999999999999])
