# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
T=[18.8,
18.8,
18.8,
18.8,
21.7,
22,
22.1,
22.1,
22.1,
22.1,
22.1,
22.1,
22.1,
22.1]
t=[0.5*i for i in range(len(T))]
t=np.array(t)
t=t-1.5
t
# Out:
# array([-1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,
#         4. ,  4.5,  5. ])

# %%
n=0.15612
m_kw=0.5204*0.3*36.46
m_zas=6.182
m_wody=520.4-m_kw
C_zas=3.24 #[J/g*K]
C_kw=0.812
C_wody=75.4/18.01528 
K=m_kw*C_kw+m_wody*C_wody+m_zas*C_zas
DeltaT=22.1-18.8
H=-K*DeltaT/(1000*n)
H, K
# Out:
# (-46.0562020919674, 2178.877051696348)

# %%
plt.scatter(t,T,color='k',marker='.')
plt.plot(t,T,color='r')
plt.axvline(x=0, linestyle=':', color='r')
plt.ylabel('Temperatura $T$ [°C]')
plt.xlabel('Czas $t$ [min]')
plt.show()
